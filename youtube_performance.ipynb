# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
y_tube = pd.read_csv("C:\\Users\\HP\\Desktop\\My Personal Data Projects\\youtube_channel_real_performance_analytics.csv")
y_tube.head(5)
# Out:
#    ID  Video Duration   Video Publish Time  Days Since Publish  Day  Month  \
# 0   0           201.0  2016-06-02 00:00:00                   0    2      6
# 1   1           391.0  2016-06-10 00:00:00                   8   10      6
# 2   2           133.0  2016-06-14 00:00:00                   4   14      6
# 3   3            14.0  2016-06-29 00:00:00                  15   29      6
# 4   4            45.0  2016-07-01 00:00:00                   2    1      7
#
#    Year Day of Week  Revenue per 1000 Views (USD)  \
# 0  2016    Thursday                         0.024
# 1  2016      Friday                         0.056
# 2  2016     Tuesday                         0.014
# 3  2016   Wednesday                         0.004
# 4  2016      Friday                         0.000
#
#    Monetized Playbacks (Estimate)  ...  Watched (Not Skipped) (%)  \
# 0                           723.0  ...                        0.0
# 1                           727.0  ...                        0.0
# ...

# %%
y_tube.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 70 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ID                                  364 non-null    int64
#  1   Video Duration                      364 non-null    float64
#  2   Video Publish Time                  364 non-null    object
#  3   Days Since Publish                  364 non-null    int64
#  4   Day                                 364 non-null    int64
#  5   Month                               364 non-null    int64
#  6   Year                                364 non-null    int64
#  7   Day of Week                         364 non-null    object
#  8   Revenue per 1000 Views (USD)        364 non-null    float64
#  9   Monetized Playbacks (Estimate)      364 non-null    float64
#  10  Playback-Based CPM (USD)            364 non-null    float64
# ...

# %% [markdown]
# # Cleaning the data

# %%
y_tube = y_tube.loc[:, (y_tube != 0).any(axis=0)] # to drop columns that are equal to 0
y_tube.head(10)
y_tube.to_csv("cleaned_youtube_data.csv", index=False) # saved to a new file after cleaning

# %%
cleaned_ytube = pd.read_csv("C:\\Users\\HP\\Desktop\\My Personal Data Projects\\cleaned_youtube_data.csv")
cleaned_ytube.head(10)
#cleaned_ytube.info()
cleaned_ytube.describe()
# Out:
#                ID  Video Duration  Days Since Publish         Day       Month  \
# count  364.000000      364.000000          364.000000  364.000000  364.000000
# mean   181.500000      664.239011            8.406593   15.807692    6.642857
# std    105.221988      330.646183           15.371239    8.924004    3.421521
# min      0.000000        9.000000            0.000000    1.000000    1.000000
# 25%     90.750000      496.000000            3.000000    8.000000    4.000000
# 50%    181.500000      613.000000            5.000000   16.000000    7.000000
# 75%    272.250000      786.500000            9.000000   23.000000   10.000000
# max    363.000000     2311.000000          260.000000   31.000000   12.000000
#
#               Year  Revenue per 1000 Views (USD)  \
# count   364.000000                    364.000000
# mean   2018.736264                      0.112283
# std       2.530629                      0.179668
# min    2016.000000                      0.000000
# ...

# %%
cleaned_ytube.columns
# Out:
# Index(['ID', 'Video Duration', 'Video Publish Time', 'Days Since Publish',
#        'Day', 'Month', 'Year', 'Day of Week', 'Revenue per 1000 Views (USD)',
#        'Monetized Playbacks (Estimate)', 'Playback-Based CPM (USD)',
#        'CPM (USD)', 'Ad Impressions', 'Estimated AdSense Revenue (USD)',
#        'DoubleClick Revenue (USD)', 'YouTube Ads Revenue (USD)',
#        'Watch Page Ads Revenue (USD)', 'YouTube Premium (USD)', 'New Comments',
#        'Shares', 'Like Rate (%)', 'Dislikes', 'Likes', 'Unsubscribes',
#        'New Subscribers', 'End Screen Click-Through Rate (%)',
#        'End Screen Impressions', 'End Screen Clicks',
#        'Teaser Click-Through Rate (%)', 'Teaser Impressions', 'Teaser Clicks',
#        'Card Click-Through Rate (%)', 'Card Impressions', 'Card Clicks',
#        'Views per Playlist Start', 'Playlist Views',
#        'Playlist Watch Time (hours)', 'Clip Watch Time (hours)', 'Clip Views',
# ...

# %% [markdown]
# # Movie (ID) with the highest and lowest views
# * ID 228 had the highest view (670990)
# * ID 53 had the lowest views (2461)

# %%
plt.figure(figsize=(12, 6))
plt.title("Movie with the highest views")
sns.lineplot(data=cleaned_ytube, x="ID", y="Views", marker="o")
# Out:
# <Axes: title={'center': 'Movie with the highest views'}, xlabel='ID', ylabel='Views'>

# %% [markdown]
# # Year with highest and lowest movies
# * 2017 had the highest movie (126)
# * 2023 had the lowest movies(10)

# %%
count_years = cleaned_ytube.groupby("Year")["ID"].count().reset_index() # set to count the number of movies released in each year

sns.set_style("whitegrid")
plt.figure(figsize=(12,6))
plt.title("Year with the highest movies")
sns.barplot(data=count_years, x="Year", y="ID", hue="Year", legend=False, palette="viridis")
# Out:
# <Axes: title={'center': 'Year with the highest movies'}, xlabel='Year', ylabel='ID'>

# %% [markdown]
# # Which month had the highest and Lowest Likes in Year 2017?
# * In July, there were 119,013 Likes recorded, making it the month in year 2017 with the highest Likes.
# * In January, there were 4,823 Likes recorded, making it the month in year 2017 with the lowest Likes.

# %%
subscribers = cleaned_ytube[cleaned_ytube["Year"] == 2017]
cnt_subscribers = subscribers.groupby("Month")["Likes"].sum().reset_index()

plt.title("Likes in Year 2017")
sns.lineplot(data=cnt_subscribers, x="Month", y="Likes", marker="o")
# Out:
# <Axes: title={'center': 'Likes in Year 2017'}, xlabel='Month', ylabel='Likes'>

# %%
dis_subs = subscribers.groupby("Month")["Dislikes"].sum().reset_index()

plt.title("Dislikes in Year 2017")
sns.lineplot(data=dis_subs, x="Month", y="Dislikes", marker="o")
# Out:
# <Axes: title={'center': 'Dislikes in Year 2017'}, xlabel='Month', ylabel='Dislikes'>

# %% [markdown]
# # Months with the highest and lowest views in Year 2017
# * July was the month with the highest views, having 3,398,855 views.
# * January was the month with the lowest views, having 110,231 views.
#
# # Month with the highest and lowest views in Year 2020
# * January had the highest views with 348,175 views
# * February had the lowest views in 2020 with 142,820 views.

# %%
filt_year = cleaned_ytube[cleaned_ytube["Year"] == 2017]
highest_mnth = filt_year.groupby("Month")["Views"].sum().reset_index()
plt.title("Views in Year 2017")
sns.lineplot(data=highest_mnth, x="Month", y="Views", marker = "o")
# Out:
# <Axes: title={'center': 'Views in Year 2017'}, xlabel='Month', ylabel='Views'>

# %%
yr_2020 = cleaned_ytube[cleaned_ytube["Year"] == 2020]
filt_2020 = yr_2020.groupby("Month")["Views"].sum().reset_index()
filt_2020
sns.set_style("whitegrid")
plt.title("Views in Year 2020")
sns.lineplot(data=filt_2020, x="Month", y="Views", marker="o")
# Out:
# <Axes: title={'center': 'Views in Year 2020'}, xlabel='Month', ylabel='Views'>
